# %%
import networkx as nx
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
#create a an empty graph with no nodes and no edges

G = nx.Graph()

# %%
#add a single node

G.add_node(1)

# %%
#add a list of nodes

G.add_nodes_from([2, 3])

# %%
nx.draw_networkx(G, node_color='green', node_size=700)

# %% [markdown]
# # Add Edges

# %%
#adding edges to a graph
G.add_edge(1,2)

# %%
nx.draw_networkx(G)

# %%
#add edges using unpack edge tuples

e = (2,3)
G.add_edge(*e)

# %%
nx.draw_networkx(G)

# %%
#adding list of edges
G.add_edges_from([(1,2),(1,3)])

# %%
nx.draw_networkx(G)

# %%
#find number of nodes in a graph
print (G.number_of_nodes())
# Out:
# 3

# %%
#find number of egdes in a graph
print (G.number_of_edges())
# Out:
# 3

# %% [markdown]
# # Getting Graph Properties

# %% [markdown]
# ## get some properties of a graph

# %%
#getting the number of nodes is a graph
print(G.nodes())
# Out:
# [1, 2, 3]

# %%
#getting the number of edges in a graph
print(G.edges())
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
#getting the neighbor of a connected graph
print(G.neighbors(1))
# Out:
# [2, 3]

# %%
# get the degrees from a graph
print(G.degree())
# Out:
# {1: 2, 2: 2, 3: 2}

# %%
# find if a graph has a an edge
print(G.has_edge(2,3))
# Out:
# True

# %%
# find if a graph has a an edge
print(G.has_edge(2,4))
# Out:
# False

# %%
# find if there exist a node in a graph
print(G.has_node(4))
# Out:
# False

# %% [markdown]
# # Node Manipulation

# %%
H = nx.Graph()

# %%
edgelist = [(0,1),(1,2),(2,3),(0,3)]

# %%
H.add_edges_from(edgelist)

# %%
nx.draw(H,with_labels=True, node_color='cyan',node_size=700)

# %%
# remove a node
H.remove_node(3)
nx.draw(H,with_labels=True, node_color='cyan',node_size=700)

# %%
# remove a list of nodes
H.remove_nodes_from([0,1])
nx.draw(H,with_labels=True, node_color='cyan',node_size=700)

# %% [markdown]
# # Adding Attributes to our graph

# %%
B = nx.Graph(weekday='Friday', year=2016, month='October',day=14)

# %%
B.graph['day'] = 21

# %%
B.graph
# Out:
# {'day': 21, 'month': 'October', 'weekday': 'Friday', 'year': 2016}

# %%
B.graph['year'] = 2017
B.graph['month'] = 'January'

# %%
B.graph
# Out:
# {'day': 21, 'month': 'January', 'weekday': 'Friday', 'year': 2017}

# %%
nx.draw(B)

# %%
B.add_node('Spam')
nx.draw(B,with_label=True)

# %% [markdown]
# # Adding Properties to our graph

# %%
D = nx.Graph(name='Hello World ! Graph')

# %%
# Adding Properties to this graph
D.add_node(1,name='ben', email='ben@benford.com', age=45)
D.add_node(2,name='john', email='john@gmail.com', age=34)
D.add_node(3,name='cletus', email='cletus@yahoo.com', age=26)
D.add_node(4,name='emmanuel', email='emmanuel@yahoo.com', age=99)

# %%
#print the info of the graph
print(nx.info(D))
# Out:
# Name: Hello World ! Graph
# Type: Graph
# Number of nodes: 4
# Number of edges: 0
# Average degree:   0.0000

# %%
#print the properties of the graph
print(D.nodes(data=True))
# Out:
# [(1, {'age': 45, 'name': 'ben', 'email': 'ben@benford.com'}), (2, {'age': 34, 'name': 'john', 'email': 'john@gmail.com'}), (3, {'age': 26, 'name': 'cletus', 'email': 'cletus@yahoo.com'}), (4, {'age': 99, 'name': 'emmanuel', 'email': 'emmanuel@yahoo.com'})]

# %%
#draw the graph
nx.draw_networkx(D)
